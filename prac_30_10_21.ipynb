# %% [markdown]
# # Exercise

# %% [markdown]
# ## Import a dataset from seaborn called exercise

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('exercise')
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %% [markdown]
# ## Check your directory

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\Hanna'

# %% [markdown]
# ## Import your libraries: pandas and numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load your iris dataset

# %%
iris = pd.read_csv('iris data.csv', header = None)

# %% [markdown]
# ## Get first 5 rows

# %%
iris.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %% [markdown]
# ## Get the shape of the dataset

# %%
iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ## Rename your columns to sepal_length, sepal_width, petal_length, petal_width then display the first five rows

# %%
col_name = ['sepal_length','sepal_width','petal_length','petal_width','species']
iris.columns = col_name

# %% [markdown]
# ## Get info of your dataste

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ## get description of your dataset

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## group data by species

# %%
iris.groupby('species').count()
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa                50           50            50           50
# Iris-versicolor            50           50            50           50
# Iris-virginica             50           50            50           50

# %%
iris.groupby('species').size()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
iris['count'] =1
iris.groupby(['species', 'sepal_length']).count()['count']
# Out:
# species          sepal_length
# Iris-setosa      4.3             1
#                  4.4             3
#                  4.5             1
#                  4.6             4
#                  4.7             2
#                  4.8             5
#                  4.9             4
#                  5.0             8
#                  5.1             8
#                  5.2             3
#                  5.3             1
#                  5.4             5
#                  5.5             2
#                  5.7             2
#                  5.8             1
# Iris-versicolor  4.9             1
#                  5.0             2
#                  5.1             1
#                  5.2             1
#                  5.4             1
#                  5.5             5
#                  5.6             5
#                  5.7             5
#                  5.8             3
#                  5.9             2
#                  6.0             4
# ...

# %%
iris.loc[iris['species'].str.contains('setosa')]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species  count
# 0            5.1          3.5           1.4          0.2  Iris-setosa      1
# 1            4.9          3.0           1.4          0.2  Iris-setosa      1
# 2            4.7          3.2           1.3          0.2  Iris-setosa      1
# 3            4.6          3.1           1.5          0.2  Iris-setosa      1
# 4            5.0          3.6           1.4          0.2  Iris-setosa      1
# 5            5.4          3.9           1.7          0.4  Iris-setosa      1
# 6            4.6          3.4           1.4          0.3  Iris-setosa      1
# 7            5.0          3.4           1.5          0.2  Iris-setosa      1
# 8            4.4          2.9           1.4          0.2  Iris-setosa      1
# 9            4.9          3.1           1.5          0.1  Iris-setosa      1
# 10           5.4          3.7           1.5          0.2  Iris-setosa      1
# ...

# %% [markdown]
# ## Check for missing values

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# ## You can play around with the data
