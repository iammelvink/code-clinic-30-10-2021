# %% [markdown]
# From our previous session, we got introduced to lists, tuples, series, dictionaries and finally dataframes. Where for some of these we worked with Numpy and Pandas Libraries. So let us continue and see how the operations applied on dataframes, lists, etc. and be applied to our dataset.

# %% [markdown]
# # Loading Different Datasets

# %% [markdown]
# ### Data built within seaborn library
#
# We will read in our library seaborn as the alias sns and get the names of the datasets that are built-in the library seaborn.

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# Call on seaborn 'sns' and get the built-in dataset diamonds.

# %%
sns.load_dataset('diamonds')
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# ## Loading a text file
#
# Sometimes you might have to include a delimiter or seperator 'sep', and this all depends in if it has one or not. E.g delimiters are '\t'. So be mindful of that.

# %%
data = pd.read_csv('pokemon.txt')
data
# Out:
#       Abomasnow
# 0          Abra
# 1         Absol
# 2      Accelgor
# 3     Aegislash
# 4    Aerodactyl
# ..          ...
# 801     Zoroark
# 802       Zorua
# 803       Zubat
# 804    Zweilous
# 805     Zygarde
#
# [806 rows x 1 columns]

# %% [markdown]
# It is important to know the directory for your Jupyter Notebook. So if you are not certain of it. Then call on the library os and use os.getcwd() to help you find our where you directory is and in my case it is C:\\Users\\Hanna. Please check yours before mosing forward with this notebook to ensure that your code will work. As you can see from the image below.

# %%
from IPython.display import Image
Image(filename =  "directory.png", width=900, height=900)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Hanna'

# %% [markdown]
# We find ourselves working with data online were we might not want to keep the data on our device. So if you are working with data from gethub. Make sure that you copy the correct url and that the last bit on information contains the name of oue dataset so that it will load your data onto Jupyter Notebook. And for codes on laoding data from other sites, you can search for such codes online and you will gain access to such.
#
# Now our variable ur1_data contains our url for our dataset. So using the pandas 'pd' library we read in that url and call that dataset data_csv. And finally display the first five rows of our dataset.

# %% [markdown]
# ## loading a file from github

# %%
url_data = (r'https://raw.githubusercontent.com/oderofrancis/rona/main/Countries-Continents.csv')

data_csv = pd.read_csv(url_data)

data_csv.head()
# Out:
#   Continent       Country
# 0    Africa       Algeria
# 1    Africa        Angola
# 2    Africa         Benin
# 3    Africa      Botswana
# 4    Africa  Burkina Faso

# %% [markdown]
# People have various reasons as to why they include images as part of their code. And for some it could help with explaining if perhaps it contains some image you want to use.
#
# The image I am using is stored on my device, however you can load an image from online as well. Importing image from IPython.display, we use Image to call on our image and add a width and height where our image will be displayed in a square format. Please ensure that your image is stored on your directory if you are using an image from your device.

# %% [markdown]
# ### Loading an image

# %%
from IPython.display import Image
Image(filename =  "pokemon.jpg", width=900, height=900)

# %% [markdown]
# ## Loading data into Pandas

# %% [markdown]
# ## Information about the dataset
#
#
# * https://www.pokemon.com/us/pokedex/
# * https://bulbapedia.bulbagarden.net/wiki/List_of_Pok%C3%A9mon_by_National_Pok%C3%A9dex_number
#
# This data set includes 721 Pokemon, including their number, name, first and second type, and basic stats: HP, Attack, Defense, Special Attack, Special Defense, and Speed.
#
# This are the raw attributes that are used for calculating how much damage an attack will do in the games. This dataset is about the pokemon games (NOT pokemon cards or Pokemon Go).
#
# The data as described by Myles O'Neill is:
#
# * #: ID for each pokemon
# * Name: Name of each pokemon
# * Type 1: Each pokemon has a type, this determines weakness/resistance to attacks or The Primary Type of the Pokemon.
# * Type 2: Some pokemon are dual type and have 2 or The Secondary Type of the Pokemon.
# * Total: sum of all stats that come after this, a general guide to how strong a pokemon is
# * HP: hit points, or health, defines how much damage a pokemon can withstand before fainting
# * Attack: the base modifier for normal attacks (eg. Scratch, Punch)
# * Defense: the base damage resistance against normal attacks
# * SP Atk: special attack, the base modifier for special attacks (e.g. fire blast, bubble beam)
# * SP Def: the base damage resistance against special attacks
# * Speed: determines which pokemon attacks first each round

# %%
from IPython.display import Image
Image(filename =  "poke.png", width=900, height=900)

# %% [markdown]
# This is the dataset that we will be working with. So using our pandas library as alias pd. We will name our dataframe poke which conatins our dataset. And using pd.read_csv allows us to read our dataset Pokemon_data.csv, and finally display the first 5 rows of own dataset.

# %%
import pandas as pd
poke = pd.read_csv('Pokemon_data.csv')

## first five columns 
poke.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# This allows us to print() all the columns 'variables' of our data poke.

# %%
## headers 
print(poke.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# We will display all the data found under the column Name and the rest can be done for all variables found within the data poke.

# %%
## read a column
poke['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %% [markdown]
# We use iloc indexing to view all the columns 'variables' in our data where we display the 1'first' row to 3'third' row ` (n-1).

# %%
## read a row 
poke.iloc[1:4]
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False

# %% [markdown]
# We shall use indexing iloc to display the value "Venusaur" from our column Name which is the 1st column by position. So iloc will scan within the dataframe and retrieve the element in the 2nd row position and from the 1st row.

# %%
## read a specific location(row, col)
poke.iloc[2,1]
# Out:
# 'Venusaur'

# %% [markdown]
# Using a for loop we can again display the values from our Column 'Name'.

# %%
for index, row in poke.iterrows():
    print(index,row['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran♀
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran♂
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# 66 Poliwhirl
# ...

# %% [markdown]
# The code poke.info() gives us a summaries output of our data poke. Firstly it is a pandas dataframe with 800 entries "rows", and 13 columns. And for each column "variable", we note all the number of variables along with it's datatype. And using this we can find out which variables have missing values and if their datatype is correct based on how the data was presented when we read it in initially.

# %%
poke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# We use the isnull() to find any missinf values in our dataset. Where it displays a dataframe and indicates if each element has a missing value or not.

# %%
poke.isnull()
# Out:
#          #   Name  Type 1  Type 2  Total     HP  Attack  Defense  Sp. Atk  \
# 0    False  False   False   False  False  False   False    False    False
# 1    False  False   False   False  False  False   False    False    False
# 2    False  False   False   False  False  False   False    False    False
# 3    False  False   False   False  False  False   False    False    False
# 4    False  False   False    True  False  False   False    False    False
# ..     ...    ...     ...     ...    ...    ...     ...      ...      ...
# 795  False  False   False   False  False  False   False    False    False
# 796  False  False   False   False  False  False   False    False    False
# 797  False  False   False   False  False  False   False    False    False
# 798  False  False   False   False  False  False   False    False    False
# 799  False  False   False   False  False  False   False    False    False
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# We got the sum of the missing values for each column "variable".

# %%
poke.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
(386 /800)*100
# Out:
# 48.25

# %% [markdown]
# If you had to do missing value treatment, it would really affect your predictions because there are close to 50% of your missing values in your variable Type 2. So we will drop this column becuse there are pokemons that do not have a type 2 and because there is close to 50% missing values. However there are ways to justify why you drop or delete columns with missing values.
#
# Using the drop, deleted our column Type 2 and axis = 1 indicates that it is a column where as we use axis =0, it is used for rows.

# %%
poke = poke.drop('Type 2', axis = 1)

# %% [markdown]
# We will filter our data for our Type 1 column having the value 'fire' and we will do this using loc.

# %%
## filter your data 
## conditional statements 
poke.loc[poke['Type 1'] == 'Fire']
# Out:
#        #                       Name Type 1  Total   HP  Attack  Defense  \
# 4      4                 Charmander   Fire    309   39      52       43
# 5      5                 Charmeleon   Fire    405   58      64       58
# 6      6                  Charizard   Fire    534   78      84       78
# 7      6  CharizardMega Charizard X   Fire    634   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    634   78     104       78
# 42    37                     Vulpix   Fire    299   38      41       40
# 43    38                  Ninetales   Fire    505   73      76       75
# 63    58                  Growlithe   Fire    350   55      70       45
# 64    59                   Arcanine   Fire    555   90     110       80
# 83    77                     Ponyta   Fire    410   50      85       55
# 84    78                   Rapidash   Fire    500   65     100       70
# 135  126                     Magmar   Fire    495   65      95       57
# ...

# %% [markdown]
# Next we will filter our data with our column 'Type 1' having the entry Grass. So we will return our dataframe with that filtering.

# %%
poke.loc[poke['Type 1'] == 'Grass']
# Out:
#        #                   Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison    318   45      49       49
# 1      2                Ivysaur  Grass    Poison    405   60      62       63
# 2      3               Venusaur  Grass    Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison    625   80     100      123
# 48    43                 Oddish  Grass    Poison    320   45      50       55
# ..   ...                    ...    ...       ...    ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN    313   56      61       65
# 719  651              Quilladin  Grass       NaN    405   61      78       95
# 720  652             Chesnaught  Grass  Fighting    530   88     107      122
# 740  672                 Skiddo  Grass       NaN    350   66      65       48
# 741  673                 Gogoat  Grass       NaN    531  123     100       62
#
# ...

# %% [markdown]
# ## sorting and describe

# %% [markdown]
# Using the poke.describe(), we will display a summary of all our numerical 'integer type' columns within our dataset. And with a bit of stats background you will be able to draw some analysis out of your data.
# Note: this also gives us the 5- number summary which is similar to the values we will get from a box and whisker plot.
# * min = lowest value for that column
# * 25% = 25th percentile for rach column
# * 50% = median for each column
# * 75% = 75th percentile for each column
# * max = maximum value for each column
#
# And the remaining analysis is just:
# * count =  the total entries for each column
# * mean =  the average for each column
# * std = is the standard deviation for each column

# %%
poke.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %% [markdown]
# We can also sort our entries of a specific column in this case "Name" and get the names of the Pokemon in alphabetical order.

# %%
## sort in ascending order by name 
poke.sort_values('Name')
# Out:
#        #                     Name   Type 1  Type 2  Total   HP  Attack  \
# 510  460                Abomasnow    Grass     Ice    494   90      92
# 511  460  AbomasnowMega Abomasnow    Grass     Ice    594   90     132
# 68    63                     Abra  Psychic     NaN    310   25      20
# 392  359                    Absol     Dark     NaN    465   65     130
# 393  359          AbsolMega Absol     Dark     NaN    565   65     150
# ..   ...                      ...      ...     ...    ...  ...     ...
# 632  571                  Zoroark     Dark     NaN    510   60     105
# 631  570                    Zorua     Dark     NaN    330   40      65
# 46    41                    Zubat   Poison  Flying    245   40      45
# 695  634                 Zweilous     Dark  Dragon    420   72      85
# 794  718         Zygarde50% Forme   Dragon  Ground    600  108     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# We will sort out pokemon names using the column 'Names' in descending order.

# %%
## sort in descending order 
poke.sort_values('Name', ascending = False)
# Out:
#        #                     Name   Type 1  Type 2  Total   HP  Attack  \
# 794  718         Zygarde50% Forme   Dragon  Ground    600  108     100
# 695  634                 Zweilous     Dark  Dragon    420   72      85
# 46    41                    Zubat   Poison  Flying    245   40      45
# 631  570                    Zorua     Dark     NaN    330   40      65
# 632  571                  Zoroark     Dark     NaN    510   60     105
# ..   ...                      ...      ...     ...    ...  ...     ...
# 393  359          AbsolMega Absol     Dark     NaN    565   65     150
# 392  359                    Absol     Dark     NaN    465   65     130
# 68    63                     Abra  Psychic     NaN    310   25      20
# 511  460  AbomasnowMega Abomasnow    Grass     Ice    594   90     132
# 510  460                Abomasnow    Grass     Ice    494   90      92
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# We will sort our dataframe with our columns "Type 1" & "HP". In ascending order for both.

# %%
poke.sort_values(['Type 1', 'HP'], ascending = True)
# Out:
#        #       Name Type 1  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja    Bug    236    1      90       45       30       30
# 230  213    Shuckle    Bug    505   20      10      230       10      230
# 462  415     Combee    Bug    244   30      30       42       30       42
# 603  543   Venipede    Bug    260   30      45       59       30       39
# 314  290    Nincada    Bug    266   31      45       90       30       30
# ..   ...        ...    ...    ...  ...     ...      ...      ...      ...
# 142  131     Lapras  Water    535  130      85       80       85       95
# 145  134   Vaporeon  Water    525  130      65       60      110       95
# 350  320    Wailmer  Water    400  130      70       35       70       35
# 655  594  Alomomola  Water    470  165      75       80       40       45
# 351  321    Wailord  Water    500  170      90       45       90       45
#
#      Speed  Generation  Legendary
# 316     40           3      False
# ...

# %% [markdown]
# We will use our columns "Type 1" & "HP" for sorting our dataframe but Type 1 will be in ascending order and HP will go from highest value to lowest.

# %%
poke.sort_values(['Type 1', 'HP'], ascending = [1,0])
# Out:
#        #                     Name Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 520  469                  Yanmega    Bug    515  86      76       86      116
# 698  637                Volcarona    Bug    550  85      60       65      135
# 231  214                Heracross    Bug    500  80     125       75       40
# 232  214  HeracrossMega Heracross    Bug    600  80     185      115       40
# 678  617                 Accelgor    Bug    495  80      70       40      100
# ..   ...                      ...    ...    ...  ..     ...      ...      ...
# 106   98                   Krabby  Water    325  30     105       90       25
# 125  116                   Horsea  Water    295  30      40       70       70
# 129  120                   Staryu  Water    340  30      45       55       70
# 139  129                 Magikarp  Water    200  20      10       55       15
# 381  349                   Feebas  Water    200  20      15       20       10
#
# ...

# %% [markdown]
# ## Making changes to our data

# %% [markdown]
# We will be dropping our column total so that we can see our we obtained it.

# %%
#drop a column
poke = poke.drop(columns = ['Total'])

# %% [markdown]
# Just displaying our data to see of our column is really dropped or not

# %%
poke.head()
# Out:
#    #                   Name Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1              Bulbasaur  Grass  45      49       49       65       65
# 1  2                Ivysaur  Grass  60      62       63       80       80
# 2  3               Venusaur  Grass  80      82       83      100      100
# 3  3  VenusaurMega Venusaur  Grass  80     100      123      122      120
# 4  4             Charmander   Fire  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %% [markdown]
# Now we take our data poke and call our new column Total and it holds the sum of the following columns : 'HP' + 'Attack' + 'defense' + 'Sp. Def' +  'Sp. Atk' + 'Speed'. And finally get the first 5 rows of our new data.

# %%
## add all the 'stats' or values of the dataset

poke['Total'] = poke['HP'] + poke['Attack'] + poke['Defense'] + poke['Sp. Def'] + poke['Sp. Atk'] + poke['Speed']
poke.head()
# Out:
#    #                   Name Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1              Bulbasaur  Grass  45      49       49       65       65
# 1  2                Ivysaur  Grass  60      62       63       80       80
# 2  3               Venusaur  Grass  80      82       83      100      100
# 3  3  VenusaurMega Venusaur  Grass  80     100      123      122      120
# 4  4             Charmander   Fire  39      52       43       60       50
#
#    Speed  Generation  Legendary  Total
# 0     45           1      False    318
# 1     60           1      False    405
# 2     80           1      False    525
# 3     80           1      False    625
# 4     65           1      False    309

# %% [markdown]
# This is another way to get the same output, where we add our columns using indesing. With the help of iloc, we will include all our rows for the mentioned columns, from the 4th to the 9th columns and get the sum for each of the respctive rows and all those will give us our column 'Total'.

# %%
## adding in a different way, all rows and just the columns with values we want to sum
# poke['Total'] = poke.iloc[:, 4:10].sum(axis = 1)

# %% [markdown]
# Shifting the position of our column Total from where it was at the rear, to come before our numerical data type columns.
#
# So we will create a list called cols, which contains all the columns in our data poke with thier values. Then we will assemble our new dataset called poke where we iclude our first three columns + our last column through negative indexing + the columns from the 4th position to the 11th position to get the dataframe generated and displayed below with the first five rows.

# %%
## move the position of a column 
cols = list(poke.columns.values)
poke = poke[cols[0:4] + [cols[-1]]+ cols[4:12]]
poke.head()
# Out:
#    #                   Name Type 1  HP  Total  Total  Total  Total  Attack  \
# 0  1              Bulbasaur  Grass  45    318    318    318    318      49
# 1  2                Ivysaur  Grass  60    405    405    405    405      62
# 2  3               Venusaur  Grass  80    525    525    525    525      82
# 3  3  VenusaurMega Venusaur  Grass  80    625    625    625    625     100
# 4  4             Charmander   Fire  39    309    309    309    309      52
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       49       65       65     45           1      False
# 1       63       80       80     60           1      False
# 2       83      100      100     80           1      False
# 3      123      122      120     80           1      False
# 4       43       60       50     65           1      False

# %% [markdown]
# ## Saving our new csv

# %% [markdown]
# These lines our codes, are for saving a datasets either as a csv, xlsx or text and you can name them whatever you want but it is important to include the correct type when renaming your saved data.

# %%
## modified.csv is the new data set name and you can remove your indexes if you want 
##poke.to_csv('modified.csv', index = False)
## poke.to_excel('modify.xlsx', index = False)
##poke.to_csv('modify.text', index = False, sep ='\t')

# %% [markdown]
# Filtering your data to get all Pokemon in the 'Name' column containing the string or name 'Mega'.

# %%
## filter out rows that contain a word ' Mega'
poke.loc[poke['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 3      3      VenusaurMega Venusaur     Grass    Poison    625   80     100
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    634   78     104
# 12     9    BlastoiseMega Blastoise     Water       NaN    630   79     103
# 19    15      BeedrillMega Beedrill       Bug    Poison    495   65     150
# 23    18        PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 71    65      AlakazamMega Alakazam   Psychic       NaN    590   55      50
# 87    80        SlowbroMega Slowbro     Water   Psychic    590   95      75
# 102   94          GengarMega Gengar     Ghost    Poison    600   60      65
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN    590  105     125
# 137  127          PinsirMega Pinsir       Bug    Flying    600   65     155
# ...

# %% [markdown]
# Remove all the rows conating the name or string 'Mega'.

# %%
## remove the word 'mega'
poke.loc[~poke['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318   45      49       49
# 1      2              Ivysaur    Grass  Poison    405   60      62       63
# 2      3             Venusaur    Grass  Poison    525   80      82       83
# 4      4           Charmander     Fire     NaN    309   39      52       43
# 5      5           Charmeleon     Fire     NaN    405   58      64       58
# ..   ...                  ...      ...     ...    ...  ...     ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795  719              Diancie     Rock   Fairy    600   50     100      150
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# Using regular expressions are helpful with filtering or imposing more then condition.
# * or = |
# * and = &
# etc.
#
# So in this case we want to look through our column 'Type 1' and get all Pokemon information conating either Grass or Fire.

# %%
## regular expressions 
import re
poke.loc[poke['Type 1'].str.contains('Fire|Grass', regex =True)]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 4      4             Charmander   Fire     NaN    309   39      52       43
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 735  667                 Litleo   Fire  Normal    369   62      50       58
# 736  668                 Pyroar   Fire  Normal    507   86      68       72
# 740  672                 Skiddo  Grass     NaN    350   66      65       48
# 741  673                 Gogoat  Grass     NaN    531  123     100       62
# 799  721              Volcanion   Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# Runing the same code as above, it is just that, we will ignore if these words are lower or upper case, as we want to get the exact number within our dataset.

# %%
# the re.I ignores whether the word is upper or lower case
#poke.loc[poke['Type 1'].str.contains('fire|grass',flags = re.I, regex =True)]

# %% [markdown]
# We want to go through our caolumn 'Name' and get all Pokemons containing the strings pi, ot can be at the start, center, or the end.

# %%
## get all pokemon names that start with pi from a -z and * means zero or more
poke.loc[poke['Name'].str.contains('pi[a-z]*', regex =True)]
#poke.loc[poke['Name'].str.contains('^pi[a-z]*', regex =True)]
# Out:
#        #        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 13    10    Caterpie      Bug     NaN    195   45      30       35       20
# 42    37      Vulpix     Fire     NaN    299   38      41       40       50
# 76    70  Weepinbell    Grass  Poison    390   65      90       50       85
# 84    78    Rapidash     Fire     NaN    500   65     100       70       80
# 181  167    Spinarak      Bug  Poison    250   40      60       40       40
# 189  175      Togepi    Fairy     NaN    245   35      20       65       40
# 202  187      Hoppip    Grass  Flying    250   35      35       40       35
# 266  247     Pupitar     Rock  Ground    410   70      84       70       65
# 345  316      Gulpin   Poison     NaN    302   70      43       53       43
# 357  326     Grumpig  Psychic     NaN    470   80      45       65       90
# 358  327      Spinda   Normal     NaN    360   60      60       60       60
# ...

# %% [markdown]
# ## conditional changes

# %% [markdown]
# We want to change the value fire within column 'Type 1' to Flammer.

# %%
# change the quantity within your cell to something else
poke.loc[poke['Type 1'] == 'Fire', 'Type 1'] = 'Flammer'

# %% [markdown]
# We have named all our Pokemon with a Type 1 of Fire to be legendary.

# %%
## let all pokemons of fire to be legendary
poke.loc[poke['Type 1'] == 'Fire', 'Legendary'] = True
poke.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1       True

# %% [markdown]
# ## Aggregate Statistics (Groupby)

# %% [markdown]
# We are going our type 1 column and using that as our indexing column, and filtering our data to get all the defense for the type 1 enries from highest to lowest. So we will see which type has the highest defense.

# %%
## do specific types have good abilities 
poke.groupby(['Type 1']).mean().sort_values('Defense', ascending = False)
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Steel     442.851852  487.703704  65.222222   92.703704  126.370370
# Rock      392.727273  453.750000  65.363636   92.863636  100.795455
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Water     303.089286  430.455357  72.062500   74.151786   72.946429
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# Bug       334.492754  378.927536  56.884058   70.971014   70.724638
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Poison    251.785714  399.142857  67.250000   74.678571   68.821429
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Psychic   380.807018  475.947368  70.631579   71.456140   67.684211
# ...

# %% [markdown]
# Now we will see from our type 1 column, which type has the highest attack.

# %%
poke.groupby(['Type 1']).mean().sort_values('Attack', ascending = False)
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Rock      392.727273  453.750000  65.363636   92.863636  100.795455
# Steel     442.851852  487.703704  65.222222   92.703704  126.370370
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Poison    251.785714  399.142857  67.250000   74.678571   68.821429
# Water     303.089286  430.455357  72.062500   74.151786   72.946429
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Normal    319.173469  401.683673  77.275510   73.469388   59.846939
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# ...

# %% [markdown]
# ### You can contine and do more filtering for the different columns that affect the  type 1 of the Pokemons.

# %% [markdown]
# You can group by by Type 1 of the Pokemon and simply get the count 'sum' for each column against the type of the various Pokemons.

# %%
poke.groupby(['Type 1']).count()
# Out:
#             #  Name  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1
# Bug        69    69      52     69   69      69       69       69       69
# Dark       31    31      21     31   31      31       31       31       31
# Dragon     32    32      21     32   32      32       32       32       32
# Electric   44    44      17     44   44      44       44       44       44
# Fairy      17    17       2     17   17      17       17       17       17
# Fighting   27    27       7     27   27      27       27       27       27
# Fire       52    52      24     52   52      52       52       52       52
# Flying      4     4       2      4    4       4        4        4        4
# Ghost      32    32      22     32   32      32       32       32       32
# Grass      70    70      37     70   70      70       70       70       70
# Ground     32    32      19     32   32      32       32       32       32
# ...

# %% [markdown]
# This just displays the number of Type 1's for the Pokemons.

# %%
## tidy up the data and get the amounts of each pokemon type
poke['count'] = 1
poke.groupby(['Type 1']).count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %% [markdown]
# This groups our type 1 and type 2 for our Pokemons and get the count for each. So it takes the entries in our Type 1 as index and gives the number of corresponding type 2 entries for that Type 1.
#
# Example for the entry Bug for Type 1 has an 2 electric, 2 fighting, 2 fire, 14 flying, 1 ghost etc. for type 2.

# %%
poke.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# ### See you soon!
